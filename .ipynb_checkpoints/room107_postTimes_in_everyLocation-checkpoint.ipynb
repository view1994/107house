# %%
import pymongo
import charts
# Out:
# Server running in the folder /Users/tanyashi/Python/View's homework/107house at 127.0.0.1:53281

# %%
client=pymongo.MongoClient('localhost',27017)
room107=client['room107']
room_info=room107['room_info']

# %%
for i in room_info.find().limit(300):
    print(i['locations'][0].split('&nbsp'))
# Out:
# ['', '朝阳', '健翔桥华严里']
# ['', '朝阳', '磨房北里229号楼1单元501']
# ['', '海淀', '北京师范大学南门正对面']
# ['', '朝阳', '磨坊北里小区']
# ['', '朝阳', '兴华公寓']
# ['', '朝阳', '兴华公寓']
# ['', '朝阳', '金隅汇星苑']
# ['', '朝阳', '雅城一里']
# ['', '海淀', '华清嘉园9号楼1401']
# ['', '朝阳', '常营中弘北京像素北区']
# ['', '海淀', '六道口学院路回迁安置房八家嘉园东门对面新小区']
# ['', '海淀', '五道口学院路回迁安置房八家嘉园东门对面新小区']
# ['', '海淀', '学院路回迁安置房八家嘉园东门对面新小区']
# ['', '海淀', '学院路回迁安置房建清园北面新小区']
# ['', '海淀', '学院路回迁安置房逸成东苑北面新小区']
# ['', '海淀', '学院路回迁安置房逸成东苑北面新小区']
# ['', '海淀', '学院路回迁安置房建清园北面新小区']
# ['', '海淀', '学院路回迁安置房八家嘉园东门对面新小区']
# ['', '海淀', '学院路回迁安置房八家嘉苑东门对面新小区']
# ['', '海淀', '学院路安置房八家嘉园东门对面新小区']
# ['', '海淀', '学院路安置房建清园北边新小区']
# ['', '海淀', '学院路安置房逸成东苑北面新小区']
# ['', '海淀', '学院路回迁安置房八家嘉园东门对面新小区']
# ['', '海淀', '学院路安置房八家嘉园东门新小区']
# ['', '海淀', '学院路安置房建清园北面新小区']
# ['', '海淀', '学院路回迁安置房逸成东苑北面新小区']
# ['', '海淀', '学院路安置房建清园北面新小区']
# ['', '海淀', '学院路回迁安置房八家嘉苑东门对面新小区']
# ['', '海淀', '学院路安置房小区八家嘉园东门对面']
# ['', '海淀', '学院路安置房小区逸成东苑北面新小区']
# ['', '海淀', '学院路安置房在建清园北边']
# ['', '海淀', '学院路安置房八家嘉园东门对面新小区']
# ['', '海淀', '学院路北端安置房小区']
# ['', '海淀', '学院路北端安置房小区']
# ['', '海淀', '学院路北端安置房小区']
# ['', '海淀', '学院路安置房逸成东苑对面新小区']
# ['', '海淀', '学院路安置房逸成东苑对面新小区']
# ['', '海淀', '学院路安置房八家嘉园东面新小区']
# ['', '海淀', '学院路安置房逸成东苑对面新小区']
# ['', '海淀', '学院路安置房八家嘉园东面新小区']
# ['', '海淀', '学院路安置房八家嘉园东面新小区']
# ['', '海淀', '学院路安置房八家嘉园东面新小区']
# ['', '海淀', '学院路安置房八家嘉园东门对面']
# ['', '朝阳', '泰福苑']
# ['', '朝阳', '慧忠北里']
# ['', '朝阳', '龙祥嘉园']
# ['', '丰台', '南木樨园甲二号楼一单元...']
# ['', '通州', '梨园玉桥西里']
# ['', '朝阳', '晨曦园']
# ['', '朝阳', '百环家园']
# ['', '朝阳', '望京西园三区']
# ['', '朝阳', '夏都家园']
# ['', '昌平', '京科苑']
# ['', '丰台', '马家堡角门西里晨光小区']
# ['', '昌平', '紫金新干线4区']
# ['', '丰台', '赵公口慧时欣园']
# ['', '丰台', '卢沟桥丰台西局玉璞家园']
# ['', '通州', '新华联锦园']
# ['', '昌平', '龙泽苑西区']
# ['', '海淀', '西北旺颐和山庄']
# ['', '朝阳', '沿海赛洛城北区']
# ['', '朝阳', '都市家公寓']
# ['', '朝阳', '圣馨家园']
# ['', '昌平', '云趣园三区']
# ['', '朝阳', '安慧北里秀园']
# ['', '丰台', '政馨园三区']
# ['', '丰台', '怡然家园6号院']
# ['', '丰台', '李村一号楼']
# ['', '朝阳', '香江北岸']
# ['', '昌平', '紫金新干线一区']
# ['', '丰台', '成寿寺路21号院']
# ['', '丰台', '新宫阳关星苑']
# ['', '朝阳', '北京朝阳区定福庄南里四...']
# ['', '朝阳', '安贞黄寺后身36号院']
# ['', '朝阳', '管庄管庄新村D区']
# ['', '朝阳', '北苑北京城建世华泊郡']
# ['', '朝阳', '新纪家园']
# ['', '丰台', '紧邻4号10号线角门西']
# ['', '朝阳', '保利嘉园']
# ['', '朝阳', '保利嘉园']
# ['', '朝阳', '保利嘉园']
# ['', '朝阳', '新建村']
# ['', '朝阳', '新建村']
# ['', '朝阳', '新建村']
# ['', '朝阳', '东区国际']
# ['', '朝阳', '东区国际']
# ['', '朝阳', '东区国际']
# ['', '朝阳', '团结湖北三条']
# ['', '朝阳', '团结湖北三条']
# ['', '朝阳', '丰台区三环新城7号院']
# ['', '朝阳', '百荣嘉园']
# ['', '朝阳', '百荣嘉园']
# ['', '朝阳', '定福家园北里1号院']
# ['', '朝阳', '定福家园北里1号院']
# ['', '朝阳', '大望路']
# ['', '朝阳', '大望路']
# ['', '昌平', '龙跃苑东二区']
# ['', '朝阳', '秋实东街']
# ['', '朝阳', '中关村东路332号楼']
# ['', '朝阳', 'zuf跃进路西需浦新村']
# ['', '朝阳', '草房']
# ['', '朝阳', '草房']
# ['', '朝阳', '草房']
# ['', '朝阳', '安慧里']
# ['', '朝阳', '安慧北里秀园']
# ['', '通州', '玉桥西里']
# ['', '朝阳', '褡裢坡']
# ['', '朝阳', '褡裢坡']
# ['', '朝阳', '草房']
# ['', '朝阳', '常营']
# ['', '丰台', '成寿寺']
# ['', '丰台', '成寿寺']
# ['', '朝阳', '大望路']
# ['', '朝阳', '大望路']
# ['', '朝阳', '青年路']
# ['', '朝阳', '青年路']
# ['', '朝阳', '褡裢坡']
# ['', '朝阳', '常营']
# ['', '朝阳', '管庄']
# ['', '朝阳', '草房']
# ['', '丰台', '成寿寺']
# ['', '西城', '时代之光名苑']
# ['', '丰台', '角门西']
# ['', '丰台', '中海城圣朝非']
# ['', '朝阳', '雅成一里']
# ['', '朝阳', '管庄西里']
# ['', '朝阳', '连心园']
# ['', '朝阳', '美景东方']
# ['', '丰台', '城苑南里']
# ['', '通州', '新华联家园南区（八通线果园站）']
# ['', '朝阳', '望京西园三区']
# ['', '朝阳', '蓝色家族']
# ['', '朝阳', '望京新城']
# ['', '朝阳', '望京新城']
# ['', '朝阳', '望京西园三区']
# ['', '朝阳', '慧谷时空']
# ['', '朝阳', '望京西园一区']
# ['', '朝阳', '望京花园西区']
# ['', '朝阳', '利泽西园']
# ['', '朝阳', '慧谷时空']
# ['', '朝阳', '望京西园三区']
# ['', '朝阳', '朝庭公寓']
# ['', '朝阳', '朝庭公寓']
# ['', '朝阳', '望京西园四区']
# ['', '朝阳', '南湖东园二区']
# ['', '朝阳', '南湖东园二区']
# ['', '朝阳', '南湖东园二区']
# ['', '朝阳', '金兴路2号院']
# ['', '朝阳', '慧谷阳光']
# ['', '朝阳', '花家地西里']
# ['', '朝阳', '望京西园四区']
# ['', '朝阳', '花家地南里']
# ['', '朝阳', '嘉润花园']
# ['', '朝阳', '望京花园东区']
# ['', '朝阳', '国风北京']
# ['', '朝阳', '慧谷阳光']
# ['', '通州', '戎泰苑']
# ['', '朝阳', '常营民族家园']
# ['', '朝阳', '垡头翠成馨园']
# ['', '朝阳', '石佛营朝阳区十里堡地铁6号线，主卧出租个人']
# ['', '丰台', '德鑫嘉园']
# ['', '朝阳', '双井石韵浩庭']
# ['', '朝阳', '双花园南里一区']
# ['', '朝阳', '百环家园']
# ['', '朝阳', '常营民族家园']
# ['', '昌平', '天通中苑(1-37号楼)']
# ['', '通州', 'K2百合湾']
# ['', '丰台', '宋庄路8号院']
# ['', '丰台', '政馨园二区']
# ['', '朝阳', '安慧里']
# ['', '丰台', '丰益桥丽泽景园']
# ['', '通州', '梨园云景西里南区']
# ['', '朝阳', '康惠园五号院']
# ['', '海淀', '玉泉路玉阜嘉园']
# ['', '海淀', '五路居海淀五路居61号院']
# ['', '朝阳', '坝鑫家园']
# ['', '朝阳', '北京青年城']
# ['', '丰台', '丰益花园(东区)']
# ['', '丰台', '芳星园三区']
# ['', '丰台', '木樨园南里']
# ['', '通州', '梨园东里北区']
# ['', '通州', '新翠景园']
# ['', '丰台', '花乡四合欣园']
# ['', '朝阳', '福盈家园西区']
# ['', '朝阳', '慈云寺北里']
# ['', '朝阳', '连心园']
# ['', '昌平', '百嘉城']
# ['', '朝阳', '百环花园']
# ['', '丰台', '刘家窑北里小区']
# ['', '海淀', '西北旺大牛坊(一期)']
# ['', '昌平', '紫金干线4区']
# ['', '朝阳', '大山子南里']
# ['', '昌平', '回龙观新龙城']
# ['', '昌平', '天通苑西三区']
# ['', '昌平', '兰堡公寓']
# ['', '朝阳', '劲松二区']
# ['', '朝阳', '连心园小区']
# ['', '海淀', '学院路建清园(北区)']
# ['', '丰台', '怡然家园(南区)']
# ['', '丰台', '恒富中街7号院']
# ['', '丰台', '角门角门东里小区']
# ['', '丰台', '马家堡角门西里晨光小区']
# ['', '海淀', '西苑北坞嘉园西里']
# ['', '通州', '加州小镇C区']
# ['', '西城', '赵登禹路391号']
# ['', '朝阳', '小红门鸿博家园二期B区']
# ['', '昌平', '龙兴园北区']
# ['', '朝阳', '曙光里小区41号楼']
# ['', '朝阳', '光熙门北里']
# ['', '朝阳', '花家地花家地南里']
# ['', '朝阳', '双井石韵浩庭']
# ['', '海淀', '西北旺大牛坊(一期)']
# ['', '朝阳', '常营常营']
# ['', '丰台', '青塔青塔西里']
# ['', '丰台', '小铁匠营36号院']
# ['', '丰台', '韩庄子2里']
# ['', '朝阳', '北苑林奥嘉园']
# ['', '朝阳', '武圣西里']
# ['', '海淀', '西二旗领秀新硅谷C区(西二旗西路1号院)']
# ['', '昌平', '旭辉奥都']
# ['', '昌平', '旭辉奥都']
# ['', '昌平', '小区']
# ['', '丰台', '丰台区广顺园顺八条1号院']
# ['', '昌平', '天通苑东一区']
# ['', '昌平', '天通苑东一区']
# ['', '昌平', '天通苑东一区']
# ['', '东城', '安定门内大街']
# ['', '海淀', '三义庙北里人民大学']
# ['', '朝阳', '金融街金色漫香郡']
# ['', '昌平', '国风美唐二期']
# ['', '海淀', '世纪城远大园六区一号楼']
# ['', '朝阳', '百子湾家园C区']
# ['', '西城', '天宁寺北里']
# ['', '昌平', '龙泽苑东区']
# ['', '朝阳', '金盏嘉园C区']
# ['', '海淀', '紫金庄园红五楼']
# ['', '海淀', '五道口']
# ['', '朝阳', '五里桥一街北京像素北区（草房地铁站）旁边']
# ['', '朝阳', '甘露家园']
# ['', '朝阳', '美景东方']
# ['', '西城', '东煤厂胡同11号']
# ['', '朝阳', '连心园']
# ['', '朝阳', '管庄西里']
# ['', '朝阳', '晨光家园A区']
# ['', '朝阳', '朝阳区']
# ['', '朝阳', '姚家园西里五号院']
# ['', '朝阳', '石韵浩庭']
# ['', '崇文', '天娇园']
# ['', '朝阳', '望京明苑']
# ['', '朝阳', '十里堡东里']
# ['', '石景山', '八角南路小区']
# ['', '大兴', '北京城建·北京密码']
# ['', '朝阳', '金泽家园']
# ['', '通州', '月亮湾晓镇']
# ['', '朝阳', '太阳宫圣馨家园']
# ['', '朝阳', '常营保利嘉园3号院']
# ['', '朝阳', '垡头垡头西里二区']
# ['', '朝阳', '芍药居4号院']
# ['', '通州', '新光大中心']
# ['', '昌平', '万润家园']
# ['', '丰台', '刘家窑南三环中路15号院']
# ['', '大兴', '御园小区']
# ['', '昌平', '金隅万科城']
# ['', '通州', 'DBC加州小镇']
# ['', '大兴', '首邑溪谷']
# ['', '昌平', '天通中苑']
# ['', '海淀', '双清路']
# ['', '大兴', '清澄名苑']
# ['', '昌平', '珠江摩尔公元']
# ['', '昌平', '天通苑天通苑北一区']
# ['', '通州', '翠屏里']
# ['', '通州', '大方居']
# ['', '通州', '新海北里']
# ['', '西城', '公安大学住宅区']
# ['', '通州', '群芳三园']
# ['', '东城', '北沟沿胡同']
# ['', '通州', '通州温馨家园']
# ['', '朝阳', '金隅汇景苑']
# ['', '朝阳', '芳草苑']
# ['', '通州', '砖厂北里110号楼']
# ['', '通州', '砖厂北里110号楼']
# ['', '朝阳', '金盏嘉园D区']
# ['', '朝阳', '姚家园姚家园西里七号院']
# ['', '朝阳', '三源里南小街小区']
# ['', '朝阳', '西山奥园']
# ['', '通州', '荟萃园']
# ['', '宣武', '红居街10号院']
# ['', '通州', '世界侨商中心']
# ['', '通州', '定海园']
# ['', '海淀', '温泉凯盛家园']
# ['', '朝阳', '松榆西里']
# ['', '昌平', '羊各庄新村']
# ['', '朝阳', '京棉新城']
# ['', '昌平', '华龙苑']
# ['', '朝阳', '东洲家园']
# ['', '海淀', '万寿寺北里']
# ['', '朝阳', '高碑店新村']
# ['', '大兴', '首开康乃馨城']
# ['', '丰台', '馨慧苑']
# ['', '昌平', '龙冠·冠华苑']

# %%
for i in room_info.find():
    if i['locations']:
        locations=i['locations'][0].split('&nbsp')[1:]+[i['locations'][1]if len(i['locations'])==2 else '楼层不明']
    else:
        locations=['unknown']
    room_info.update({'_id':i['_id']},{'$set':{'locations':locations}})
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:6: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.

# %%
for i in room_info.find().limit(300):
    print(i['locations'])
# Out:
# ['朝阳', '健翔桥华严里', '3层']
# ['朝阳', '磨房北里229号楼1单元501', '5层']
# ['海淀', '北京师范大学南门正对面', '12层']
# ['朝阳', '磨坊北里小区', '5层']
# ['朝阳', '兴华公寓', '14层']
# ['朝阳', '兴华公寓', '14层']
# ['朝阳', '金隅汇星苑', '4层']
# ['朝阳', '雅城一里', '24层']
# ['海淀', '华清嘉园9号楼1401', '14层']
# ['朝阳', '常营中弘北京像素北区', '2层']
# ['海淀', '六道口学院路回迁安置房八家嘉园东门对面新小区', '22层']
# ['海淀', '五道口学院路回迁安置房八家嘉园东门对面新小区', '22层']
# ['海淀', '学院路回迁安置房八家嘉园东门对面新小区', '23层']
# ['海淀', '学院路回迁安置房建清园北面新小区', '23层']
# ['海淀', '学院路回迁安置房逸成东苑北面新小区', '23层']
# ['海淀', '学院路回迁安置房逸成东苑北面新小区', '22层']
# ['海淀', '学院路回迁安置房建清园北面新小区', '5层']
# ['海淀', '学院路回迁安置房八家嘉园东门对面新小区', '22层']
# ['海淀', '学院路回迁安置房八家嘉苑东门对面新小区', '9层']
# ['海淀', '学院路安置房八家嘉园东门对面新小区', '9层']
# ['海淀', '学院路安置房建清园北边新小区', '5层']
# ['海淀', '学院路安置房逸成东苑北面新小区', '10层']
# ['海淀', '学院路回迁安置房八家嘉园东门对面新小区', '10层']
# ['海淀', '学院路安置房八家嘉园东门新小区', '8层']
# ['海淀', '学院路安置房建清园北面新小区', '10层']
# ['海淀', '学院路回迁安置房逸成东苑北面新小区', '14层']
# ['海淀', '学院路安置房建清园北面新小区', '14层']
# ['海淀', '学院路回迁安置房八家嘉苑东门对面新小区', '9层']
# ['海淀', '学院路安置房小区八家嘉园东门对面', '9层']
# ['海淀', '学院路安置房小区逸成东苑北面新小区', '9层']
# ['海淀', '学院路安置房在建清园北边', '9层']
# ['海淀', '学院路安置房八家嘉园东门对面新小区', '8层']
# ['海淀', '学院路北端安置房小区', '8层']
# ['海淀', '学院路北端安置房小区', '8层']
# ['海淀', '学院路北端安置房小区', '8层']
# ['海淀', '学院路安置房逸成东苑对面新小区', '10层']
# ['海淀', '学院路安置房逸成东苑对面新小区', '10层']
# ['海淀', '学院路安置房八家嘉园东面新小区', '9层']
# ['海淀', '学院路安置房逸成东苑对面新小区', '10层']
# ['海淀', '学院路安置房八家嘉园东面新小区', '9层']
# ['海淀', '学院路安置房八家嘉园东面新小区', '9层']
# ['海淀', '学院路安置房八家嘉园东面新小区', '9层']
# ['海淀', '学院路安置房八家嘉园东门对面', '14层']
# ['朝阳', '泰福苑', '12层']
# ['朝阳', '慧忠北里', '5层']
# ['朝阳', '龙祥嘉园', '6层']
# ['丰台', '南木樨园甲二号楼一单元...', '楼层不明']
# ['通州', '梨园玉桥西里', '6层']
# ['朝阳', '晨曦园', '楼层不明']
# ['朝阳', '百环家园', '楼层不明']
# ['朝阳', '望京西园三区', '楼层不明']
# ['朝阳', '夏都家园', '楼层不明']
# ['昌平', '京科苑', '楼层不明']
# ['丰台', '马家堡角门西里晨光小区', '6层']
# ['昌平', '紫金新干线4区', '楼层不明']
# ['丰台', '赵公口慧时欣园', '4层']
# ['丰台', '卢沟桥丰台西局玉璞家园', '6层']
# ['通州', '新华联锦园', '楼层不明']
# ['昌平', '龙泽苑西区', '楼层不明']
# ['海淀', '西北旺颐和山庄', '5层']
# ['朝阳', '沿海赛洛城北区', '楼层不明']
# ['朝阳', '都市家公寓', '楼层不明']
# ['朝阳', '圣馨家园', '楼层不明']
# ['昌平', '云趣园三区', '楼层不明']
# ['朝阳', '安慧北里秀园', '楼层不明']
# ['丰台', '政馨园三区', '楼层不明']
# ['丰台', '怡然家园6号院', '楼层不明']
# ['丰台', '李村一号楼', '楼层不明']
# ['朝阳', '香江北岸', '楼层不明']
# ['昌平', '紫金新干线一区', '楼层不明']
# ['丰台', '成寿寺路21号院', '楼层不明']
# ['丰台', '新宫阳关星苑', '8层']
# ['朝阳', '北京朝阳区定福庄南里四...', '楼层不明']
# ['朝阳', '安贞黄寺后身36号院', '5层']
# ['朝阳', '管庄管庄新村D区', '3层']
# ['朝阳', '北苑北京城建世华泊郡', '24层']
# ['朝阳', '新纪家园', '楼层不明']
# ['丰台', '紧邻4号10号线角门西', '3层']
# ['朝阳', '保利嘉园', '22层']
# ['朝阳', '保利嘉园', '22层']
# ['朝阳', '保利嘉园', '22层']
# ['朝阳', '新建村', '15层']
# ['朝阳', '新建村', '15层']
# ['朝阳', '新建村', '15层']
# ['朝阳', '东区国际', '17层']
# ['朝阳', '东区国际', '17层']
# ['朝阳', '东区国际', '17层']
# ['朝阳', '团结湖北三条', '1层']
# ['朝阳', '团结湖北三条', '1层']
# ['朝阳', '丰台区三环新城7号院', '18层']
# ['朝阳', '百荣嘉园', '1层']
# ['朝阳', '百荣嘉园', '1层']
# ['朝阳', '定福家园北里1号院', '6层']
# ['朝阳', '定福家园北里1号院', '6层']
# ['朝阳', '大望路', '楼层不明']
# ['朝阳', '大望路', '楼层不明']
# ['昌平', '龙跃苑东二区', '6层']
# ['朝阳', '秋实东街', '10层']
# ['朝阳', '中关村东路332号楼', '3层']
# ['朝阳', 'zuf跃进路西需浦新村', '4层']
# ['朝阳', '草房', '楼层不明']
# ['朝阳', '草房', '楼层不明']
# ['朝阳', '草房', '楼层不明']
# ['朝阳', '安慧里', '6层']
# ['朝阳', '安慧北里秀园', '1层']
# ['通州', '玉桥西里', '3层']
# ['朝阳', '褡裢坡', '楼层不明']
# ['朝阳', '褡裢坡', '楼层不明']
# ['朝阳', '草房', '楼层不明']
# ['朝阳', '常营', '楼层不明']
# ['丰台', '成寿寺', '楼层不明']
# ['丰台', '成寿寺', '楼层不明']
# ['朝阳', '大望路', '楼层不明']
# ['朝阳', '大望路', '楼层不明']
# ['朝阳', '青年路', '楼层不明']
# ['朝阳', '青年路', '楼层不明']
# ['朝阳', '褡裢坡', '楼层不明']
# ['朝阳', '常营', '楼层不明']
# ['朝阳', '管庄', '楼层不明']
# ['朝阳', '草房', '楼层不明']
# ['丰台', '成寿寺', '楼层不明']
# ['西城', '时代之光名苑', '楼层不明']
# ['丰台', '角门西', '3层']
# ['丰台', '中海城圣朝非', '11层']
# ['朝阳', '雅成一里', '7层']
# ['朝阳', '管庄西里', '14层']
# ['朝阳', '连心园', '3层']
# ['朝阳', '美景东方', '7层']
# ['丰台', '城苑南里', '4层']
# ['通州', '新华联家园南区（八通线果园站）', '6层']
# ['朝阳', '望京西园三区', '9层']
# ['朝阳', '蓝色家族', '19层']
# ['朝阳', '望京新城', '15层']
# ['朝阳', '望京新城', '11层']
# ['朝阳', '望京西园三区', '13层']
# ['朝阳', '慧谷时空', '11层']
# ['朝阳', '望京西园一区', '4层']
# ['朝阳', '望京花园西区', '7层']
# ['朝阳', '利泽西园', '6层']
# ['朝阳', '慧谷时空', '12层']
# ['朝阳', '望京西园三区', '6层']
# ['朝阳', '朝庭公寓', '10层']
# ['朝阳', '朝庭公寓', '8层']
# ['朝阳', '望京西园四区', '10层']
# ['朝阳', '南湖东园二区', '4层']
# ['朝阳', '南湖东园二区', '4层']
# ['朝阳', '南湖东园二区', '4层']
# ['朝阳', '金兴路2号院', '5层']
# ['朝阳', '慧谷阳光', '3层']
# ['朝阳', '花家地西里', '4层']
# ['朝阳', '望京西园四区', '12层']
# ['朝阳', '花家地南里', '4层']
# ['朝阳', '嘉润花园', '11层']
# ['朝阳', '望京花园东区', '7层']
# ['朝阳', '国风北京', '15层']
# ['朝阳', '慧谷阳光', '11层']
# ['通州', '戎泰苑', '楼层不明']
# ['朝阳', '常营民族家园', '楼层不明']
# ['朝阳', '垡头翠成馨园', '7层']
# ['朝阳', '石佛营朝阳区十里堡地铁6号线，主卧出租个人', '3层']
# ['丰台', '德鑫嘉园', '楼层不明']
# ['朝阳', '双井石韵浩庭', '14层']
# ['朝阳', '双花园南里一区', '楼层不明']
# ['朝阳', '百环家园', '楼层不明']
# ['朝阳', '常营民族家园', '楼层不明']
# ['昌平', '天通中苑(1-37号楼)', '楼层不明']
# ['通州', 'K2百合湾', '楼层不明']
# ['丰台', '宋庄路8号院', '楼层不明']
# ['丰台', '政馨园二区', '楼层不明']
# ['朝阳', '安慧里', '楼层不明']
# ['丰台', '丰益桥丽泽景园', '27层']
# ['通州', '梨园云景西里南区', '6层']
# ['朝阳', '康惠园五号院', '楼层不明']
# ['海淀', '玉泉路玉阜嘉园', '3层']
# ['海淀', '五路居海淀五路居61号院', '6层']
# ['朝阳', '坝鑫家园', '楼层不明']
# ['朝阳', '北京青年城', '楼层不明']
# ['丰台', '丰益花园(东区)', '楼层不明']
# ['丰台', '芳星园三区', '楼层不明']
# ['丰台', '木樨园南里', '楼层不明']
# ['通州', '梨园东里北区', '楼层不明']
# ['通州', '新翠景园', '楼层不明']
# ['丰台', '花乡四合欣园', '23层']
# ['朝阳', '福盈家园西区', '楼层不明']
# ['朝阳', '慈云寺北里', '楼层不明']
# ['朝阳', '连心园', '楼层不明']
# ['昌平', '百嘉城', '楼层不明']
# ['朝阳', '百环花园', '楼层不明']
# ['丰台', '刘家窑北里小区', '楼层不明']
# ['海淀', '西北旺大牛坊(一期)', '1层']
# ['昌平', '紫金干线4区', '楼层不明']
# ['朝阳', '大山子南里', '楼层不明']
# ['昌平', '回龙观新龙城', '20层']
# ['昌平', '天通苑西三区', '楼层不明']
# ['昌平', '兰堡公寓', '楼层不明']
# ['朝阳', '劲松二区', '楼层不明']
# ['朝阳', '连心园小区', '楼层不明']
# ['海淀', '学院路建清园(北区)', '5层']
# ['丰台', '怡然家园(南区)', '楼层不明']
# ['丰台', '恒富中街7号院', '楼层不明']
# ['丰台', '角门角门东里小区', '4层']
# ['丰台', '马家堡角门西里晨光小区', '6层']
# ['海淀', '西苑北坞嘉园西里', '6层']
# ['通州', '加州小镇C区', '楼层不明']
# ['西城', '赵登禹路391号', '楼层不明']
# ['朝阳', '小红门鸿博家园二期B区', '25层']
# ['昌平', '龙兴园北区', '楼层不明']
# ['朝阳', '曙光里小区41号楼', '楼层不明']
# ['朝阳', '光熙门北里', '楼层不明']
# ['朝阳', '花家地花家地南里', '6层']
# ['朝阳', '双井石韵浩庭', '3层']
# ['海淀', '西北旺大牛坊(一期)', '12层']
# ['朝阳', '常营常营', '2层']
# ['丰台', '青塔青塔西里', '3层']
# ['丰台', '小铁匠营36号院', '楼层不明']
# ['丰台', '韩庄子2里', '楼层不明']
# ['朝阳', '北苑林奥嘉园', '10层']
# ['朝阳', '武圣西里', '楼层不明']
# ['海淀', '西二旗领秀新硅谷C区(西二旗西路1号院)', '9层']
# ['昌平', '旭辉奥都', '楼层不明']
# ['昌平', '旭辉奥都', '楼层不明']
# ['昌平', '小区', '楼层不明']
# ['丰台', '丰台区广顺园顺八条1号院', '2层']
# ['昌平', '天通苑东一区', '6层']
# ['昌平', '天通苑东一区', '6层']
# ['昌平', '天通苑东一区', '6层']
# ['东城', '安定门内大街', '6层']
# ['海淀', '三义庙北里人民大学', '2层']
# ['朝阳', '金融街金色漫香郡', '1层']
# ['昌平', '国风美唐二期', '13层']
# ['海淀', '世纪城远大园六区一号楼', '5层']
# ['朝阳', '百子湾家园C区', '9层']
# ['西城', '天宁寺北里', '6层']
# ['昌平', '龙泽苑东区', '2层']
# ['朝阳', '金盏嘉园C区', '楼层不明']
# ['海淀', '紫金庄园红五楼', '1层']
# ['海淀', '五道口', '27层']
# ['朝阳', '五里桥一街北京像素北区（草房地铁站）旁边', '7层']
# ['朝阳', '甘露家园', '12层']
# ['朝阳', '美景东方', '7层']
# ['西城', '东煤厂胡同11号', '2层']
# ['朝阳', '连心园', '3层']
# ['朝阳', '管庄西里', '14层']
# ['朝阳', '晨光家园A区', '3层']
# ['朝阳', '朝阳区', '楼层不明']
# ['朝阳', '姚家园西里五号院', '楼层不明']
# ['朝阳', '石韵浩庭', '楼层不明']
# ['崇文', '天娇园', '楼层不明']
# ['朝阳', '望京明苑', '120号楼1单元']
# ['朝阳', '十里堡东里', '楼层不明']
# ['石景山', '八角南路小区', '楼层不明']
# ['大兴', '北京城建·北京密码', '楼层不明']
# ['朝阳', '金泽家园', '楼层不明']
# ['通州', '月亮湾晓镇', '楼层不明']
# ['朝阳', '太阳宫圣馨家园', '7层']
# ['朝阳', '常营保利嘉园3号院', '11层']
# ['朝阳', '垡头垡头西里二区', '1层']
# ['朝阳', '芍药居4号院', '楼层不明']
# ['通州', '新光大中心', '楼层不明']
# ['昌平', '万润家园', '楼层不明']
# ['丰台', '刘家窑南三环中路15号院', '6层']
# ['大兴', '御园小区', '楼层不明']
# ['昌平', '金隅万科城', '楼层不明']
# ['通州', 'DBC加州小镇', '楼层不明']
# ['大兴', '首邑溪谷', '楼层不明']
# ['昌平', '天通中苑', '1号楼2单元102']
# ['海淀', '双清路', '楼层不明']
# ['大兴', '清澄名苑', '楼层不明']
# ['昌平', '珠江摩尔公元', '楼层不明']
# ['昌平', '天通苑天通苑北一区', '10层']
# ['通州', '翠屏里', '楼层不明']
# ['通州', '大方居', '8号楼']
# ['通州', '新海北里', '楼层不明']
# ['西城', '公安大学住宅区', '楼层不明']
# ['通州', '群芳三园', '楼层不明']
# ['东城', '北沟沿胡同', '楼层不明']
# ['通州', '通州温馨家园', '楼层不明']
# ['朝阳', '金隅汇景苑', '楼层不明']
# ['朝阳', '芳草苑', '楼层不明']
# ['通州', '砖厂北里110号楼', '楼层不明']
# ['通州', '砖厂北里110号楼', '楼层不明']
# ['朝阳', '金盏嘉园D区', '1层']
# ['朝阳', '姚家园姚家园西里七号院', '6层']
# ['朝阳', '三源里南小街小区', '楼层不明']
# ['朝阳', '西山奥园', '楼层不明']
# ['通州', '荟萃园', '楼层不明']
# ['宣武', '红居街10号院', '楼层不明']
# ['通州', '世界侨商中心', '楼层不明']
# ['通州', '定海园', '楼层不明']
# ['海淀', '温泉凯盛家园', '楼层不明']
# ['朝阳', '松榆西里', '楼层不明']
# ['昌平', '羊各庄新村', '楼层不明']
# ['朝阳', '京棉新城', '楼层不明']
# ['昌平', '华龙苑', '楼层不明']
# ['朝阳', '东洲家园', '楼层不明']
# ['海淀', '万寿寺北里', '楼层不明']
# ['朝阳', '高碑店新村', '楼层不明']
# ['大兴', '首开康乃馨城', '楼层不明']
# ['丰台', '馨慧苑', '楼层不明']
# ['昌平', '龙冠·冠华苑', '楼层不明']

# %%
location_list=[]
for i in room_info.find():
    location_list.append(i['locations'][0])
location_index=list(set(location_list))
print(location_index,len(location_index))
# Out:
# ['海淀', '昌平', '宣武', '东城', '石景山', '大兴', '崇文', '朝阳', '房山', '丰台', '通州', '西城'] 12

# %%
post_times=[]
for i in location_index:
    post_times.append(location_list.count(i))
print(post_times)
# Out:
# [156, 79, 7, 19, 7, 51, 3, 482, 3, 134, 85, 14]

# %%
series=[]
for i,n in zip(location_index,post_times):
    series.append({'name':i,'data':[n],'type':'column'})
charts.plot(series,show='inline',options=dict(title=dict(text='post times in every location')))
# Out:
# <style>body{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;color:#555;font-family:sans-serif}
# small{font-weight:400;display:block;font-size:14px}
# code{background-color:#d3d3d3;border-radius:3px;font-family:monospace;padding:0 .5em}
# .icon.-facebook:before,.icon.-linkedin:before,.icon.-pinterest:before,.icon.-twitter:before{-moz-osx-font-smoothing:grayscale;-webkit-font-smoothing:antialiased;font-family:Post-Creator-Icons;font-style:normal;font-variant:normal;font-weight:400;line-height:1;speak:none;text-transform:none}
# @font-face{font-family:Post-Creator-Icons;src:url(fonts/Post-Creator-Icons.eot);src:url(fonts/Post-Creator-Icons.eot?#iefix) format('embedded-opentype'),url(fonts/Post-Creator-Icons.woff) format('woff'),url(fonts/Post-Creator-Icons.ttf) format('truetype'),url(fonts/Post-Creator-Icons.svg#Post-Creator-Icons) format('svg');font-weight:400;font-style:normal}
# .icon.-facebook:before{content:"\e001"}
# .icon.-linkedin:before{content:"\e002"}
# .icon.-pinterest:before{content:"\e003"}
# .icon.-twitter:before{content:"\e004"}
# .social-icons h4{display:inline-block;margin:20px 10px 0 0}
# .social-icons .icon{display:inline-block;margin:0 5px}
# body.modal-open{overflow:hidden}
# .jsoneditor table,.jsoneditor td,.jsoneditor td.tree,.jsoneditor tr{border:none;margin:0}</style>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/selectize.js/0.12.1/css/selectize.default.min.css"/>
# <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min.css"/>
#
# <div class="container-fluid">
#     <div class="row">
#         <div class="col-sm-10">
#             <input type="text" id="variable-selector">
#         </div>
#         <div class="col-sm-2">
#             <button class="btn btn-default pull-right" type="submit" id="settings-button">Settings</button>
#         </div>
#     </div>
#
#     <div class="row">
#         <div class="collapse col-xs-12" id="settings-collapse">
#             <div class="panel panel-default" style="margin-top: 20px">
#                 <div class="panel-heading"><h3 class="panel-title">Adjust chart settings</h3></div>
#                 <div class="panel-body">
#                     <div class="row">
#                         <div id="jsoneditor" class="col-md-12" style="height: 350px"></div>
#                     </div>
#                     <div class="row" style="margin-top: 10px">
#                         <div class="col-sm-4">
#                             <button type="button" class="btn btn-primary" id="save-settings">
#                                 Apply changes
#                             </button>
#                         </div>
#                         <div class="col-sm-8 text-right ">
#                             <form class="form-inline">
#                                 <div class="form-group">
#                                     <div class="input-group">
#                                         <input type="text" class="form-control" id="options-input"
#                                                placeholder="settings" style="text-align: right">
#                                         <div class="input-group-addon"><strong>.json</strong></div>
#                                     </div>
#                                 </div>
#                                 <button type="submit" class="btn btn-primary" id="options-button">Save</button>
#                             </form>
#
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <div class="row">
#         <div id="chart-container" style="min-width: 310px;"></div>
#     </div>
# </div>
#
#
# <script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.4/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/require.js/2.1.18/require.min.js"></script>
#
#
#
#
#
#
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
# //findIndex polyfill
# if (!Array.prototype.findIndex) {
#     Array.prototype.findIndex = function(predicate) {
#         if (this == null) {
#             throw new TypeError('Array.prototype.findIndex called on null or undefined');
#         }
#         if (typeof predicate !== 'function') {
#             throw new TypeError('predicate must be a function');
#         }
#         var list = Object(this);
#         var length = list.length >>> 0;
#         var thisArg = arguments[1];
#         var value;
#
#         for (var i = 0; i < length; i++) {
#             value = list[i];
#             if (predicate.call(thisArg, value, i, list)) {
#                 return i;
#             }
#         }
#         return -1;
#     };
# }
#
# if (!Array.prototype.filter) {
#     Array.prototype.filter = function(fun/*, thisArg*/) {
#         'use strict';
#
#         if (this === void 0 || this === null) {
#             throw new TypeError();
#         }
#
#         var t = Object(this);
#         var len = t.length >>> 0;
#         if (typeof fun !== 'function') {
#             throw new TypeError();
#         }
#
#         var res = [];
#         var thisArg = arguments.length >= 2 ? arguments[1] : void 0;
#         for (var i = 0; i < len; i++) {
#             if (i in t) {
#                 var val = t[i];
#
#                 // NOTE: Technically this should Object.defineProperty at
#                 //       the next index, as push can be affected by
#                 //       properties on Object.prototype and Array.prototype.
#                 //       But that method's new, and collisions should be
#                 //       rare, so use the more-compatible alternative.
#                 if (fun.call(thisArg, val, i, t)) {
#                     res.push(val);
#                 }
#             }
#         }
#
#         return res;
#     };
# }
#
# function guid() {
#     function s4() {
#         return Math.floor((1 + Math.random()) * 0x10000)
#             .toString(16)
#             .substring(1);
#     }
#     return s4() + s4() + '-' + s4() + '-' + s4() + '-' +
#         s4() + '-' + s4() + s4() + s4();
# }
#
# Array.prototype.equals = function (array) {
#     // if the other array is a false value, return
#     if (!array)
#         return false;
#
#     // compare lengths - can save a lot of time
#     if (this.length != array.length)
#         return false;
#
#     for (var i = 0, l = this.length; i < l; i++) {
#         // Check if we have nested arrays
#         if (this[i] instanceof Array && array[i] instanceof Array) {
#             // recurse into the nested arrays
#             if (!this[i].equals(array[i]))
#                 return false;
#         }
#         else if (this[i] != array[i]) {
#             // Warning - two different object instances will never be equal: {x:20} != {x:20}
#             return false;
#         }
#     }
#     return true;
# };
#
# },{}]},{},[1]);
# </script>
# <script>(function e(t,n,r){function s(o,u){if(!n[o]){if(!t[o]){var a=typeof require=="function"&&require;if(!u&&a)return a(o,!0);if(i)return i(o,!0);var f=new Error("Cannot find module '"+o+"'");throw f.code="MODULE_NOT_FOUND",f}var l=n[o]={exports:{}};t[o][0].call(l.exports,function(e){var n=t[o][1][e];return s(n?n:e)},l,l.exports,e,t,n,r)}return n[o].exports}var i=typeof require=="function"&&require;for(var o=0;o<r.length;o++)s(r[o]);return s})({1:[function(require,module,exports){
#
#
# requirejs.config({
#     "paths": {
#         "highstock": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/highstock",
#         "export": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.5/modules/exporting",
#         "more": "https://cdnjs.cloudflare.com/ajax/libs/highstock/2.1.7/highcharts-more",
#         "jsoneditor": "https://cdnjs.cloudflare.com/ajax/libs/jsoneditor/4.2.0/jsoneditor.min",
#         "selectiz
